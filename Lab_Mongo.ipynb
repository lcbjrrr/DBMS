# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/DBMS/blob/main/Lab_Mongo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mongo DB Lab

# %% [markdown]
# ## Pre-reqs

# %% [markdown]
# Create your user. Automatically create your initial cluster and database, along with the credentials.
# ![](https://pbs.twimg.com/media/HQMUl8mWAAAIZUP?format=jpg&name=medium)

# %% [markdown]
# ## Python to connect to Mongo

# %% [markdown]
# Python integrates with MongoDB primarily through the `pymongo` driver. This driver allows Python applications to connect to MongoDB databases, perform CRUD (Create, Read, Update, Delete) operations on collections and documents, and manage data programmatically. It translates Python objects (like dictionaries) into BSON (Binary JSON), which is MongoDB's native data format, and vice-versa, making data manipulation intuitive for Python developers.

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 22.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
# Connect to the local MongoDB instance
URL="mongodb://localhost:27017/"
client = MongoClient(URL)
# Equivalent to db.adminCommand({ listDatabases: 1 })
database_names = client.list_database_names()
print("List of databases:", database_names)
# Close the connection
client.close()
# Out:
# List of databases: ['admin', 'config', 'local']

# %%
from pymongo import MongoClient

# Connect to the local MongoDB instance
client = MongoClient(URL)
db = client["locals"]

# 1. db.createCollection("tab1")
# In pymongo, collection is created automatically on first insert if it doesn't exist.
# You can explicitly create it if needed, but it's often not necessary.
# db.create_collection("tab1")
print("Attempting to create collection 'tab1' (or use existing one).")
pubs = db["Pubs"]

# 2. db.tab1.insertOne({title: 'MongoDB Overview',description: 'MongoDB is no sql database'})
document1 = {"title": "Java-AI", "abstract": "Java..."}
insert_result = pubs.insert_one(document1)
print(f"Inserted document with id: {insert_result.inserted_id}")

# Add another document for better demonstration of find()
document2 = {"title": "Py-AI", "abstract": "My abstract ..."}
pubs.insert_one(document2)

# 3. db.getCollectionNames()
collection_names = db.list_collection_names()
print("Collection names in 'mydatabase':", collection_names)

# 4. db.tab1.find()
print("\nAll documents in 'tab1':")
for doc in pubs.find():
    print(doc)

# Close the connection
client.close()
# Out:
# Attempting to create collection 'tab1' (or use existing one).
# Inserted document with id: 6a8764a9044e91395558bb41
# Collection names in 'mydatabase': ['Pubs']
#
# All documents in 'tab1':
# {'_id': ObjectId('6a8764a9044e91395558bb41'), 'title': 'Java-AI', 'abstract': 'Java...'}
# {'_id': ObjectId('6a8764a9044e91395558bb42'), 'title': 'Py-AI', 'abstract': 'My abstract ...'}

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### Mongo local/colab install

# %%
# 1. Install dependencies and import the MongoDB GPG key
# !sudo apt-get update
# !sudo apt-get install -y gnupg curl
# !curl -fsSL https://pgp.mongodb.com/server-8.0.asc | sudo gpg --dearmor -o /usr/share/keyrings/mongodb-server-8.0.gpg
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [110 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,167 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.7 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,563 kB]
# ...

# %%
# 2. Add the MongoDB repository (Colab environments typically use Ubuntu 22.04 'jammy')
# !echo "deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-8.0.gpg ] https://repo.mongodb.org/apt/ubuntu $(lsb_release -sc)/mongodb-org/8.0 multiverse" | sudo tee /etc/apt/sources.list.d/mongodb-org-8.0.list
# Out:
# deb [ arch=amd64,arm64 signed-by=/usr/share/keyrings/mongodb-server-8.0.gpg ] https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0 multiverse

# %%
# 3. Reload package database and install MongoDB
# !sudo apt-get update
# !sudo apt-get install -y mongodb-org
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:5 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0 InRelease [3,005 B]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0/multiverse amd64 Packages [86.1 kB]
# Get:12 https://repo.mongodb.org/apt/ubuntu jammy/mongodb-org/8.0/multiverse arm64 Packages [85.4 kB]
# Fetched 175 kB in 1s (162 kB/s)
# Reading package lists... Done
# ...

# %%
# 4. Create the required directory for data storage and start the service
# !sudo mkdir -p /data/db
# Start mongod directly in the background, specifying the dbpath
# !mongod --dbpath /data/db > /dev/null 2>&1 &

# %% [markdown]
# ```
#
#
#
# ```
